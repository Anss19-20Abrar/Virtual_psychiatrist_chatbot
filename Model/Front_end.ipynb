# %%
# %pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
# ...

# %%
import streamlit as st

# Define a function to handle login
def login():
    st.subheader("Login")
    username = st.text_input("Username")
    password = st.text_input("Password", type="password")
    if st.button("Login"):
        # Check credentials (dummy check for demonstration)
        if username == "user" and password == "password":
            st.success("Login successful")
            # Redirect to chatbot page
            chatbot()
        else:
            st.error("Invalid username or password")

# Define a function to handle signup
def signup():
    st.subheader("Signup")
    new_username = st.text_input("New Username")
    new_password = st.text_input("New Password", type="password")
    if st.button("Signup"):
        # Implement signup logic here (not implemented for demonstration)
        st.success("Signup successful. You can now login.")

# Define a function to handle the chatbot page
def chatbot():
    st.title("Virtual Psychiatrist Chatbot")
    # Chatbot implementation here

# Define the intro page
def intro_page():
    st.title("Welcome to Virtual Psychiatrist")
    st.write("This is a virtual psychiatrist chatbot designed to provide mental health support.")
    st.write("Please login or signup to get started.")
    option = st.radio("Select an option:", ("Login", "Signup"))
    if option == "Login":
        login()
    elif option == "Signup":
        signup()

# Main function to run the application
def main():
    intro_page()

if __name__ == "__main__":
    main()
# Out:
# 2024-02-20 16:11:11.038
# ...
#   command:
#
#     streamlit run C:\Users\Anss\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# !pip install localtunnel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement localtunnel (from versions: none)
# ERROR: No matching distribution found for localtunnel

# %%
# !streamlit run C:\Users\Anss\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# & was unexpected at this time.
